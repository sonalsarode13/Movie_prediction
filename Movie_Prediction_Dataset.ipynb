# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\IMDb Movies India.csv", encoding='latin1')

# %%
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df['Duration']=df['Duration'].str.replace("min","").astype(float)

# %%
df
# Out:
#                                      Name    Year  Duration            Genre  \
# 0                                             NaN       NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)     109.0            Drama
# 2                             #Homecoming  (2021)      90.0   Drama, Musical
# 3                                 #Yaaram  (2019)     110.0  Comedy, Romance
# 4                       ...And Once Again  (2010)     105.0            Drama
# ...                                   ...     ...       ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)       NaN           Action
# 15505                               Zulmi  (1999)     129.0    Action, Drama
# 15506                           Zulmi Raj  (2005)       NaN           Action
# 15507                       Zulmi Shikari  (1988)       NaN           Action
# 15508                        Zulm-O-Sitam  (1998)     130.0    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df['Year']=df['Year'].str.strip("()").astype(float)

# %%
df
# Out:
#                                      Name    Year  Duration            Genre  \
# 0                                             NaN       NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                             #Homecoming  2021.0      90.0   Drama, Musical
# 3                                 #Yaaram  2019.0     110.0  Comedy, Romance
# 4                       ...And Once Again  2010.0     105.0            Drama
# ...                                   ...     ...       ...              ...
# 15504                 Zulm Ko Jala Doonga  1988.0       NaN           Action
# 15505                               Zulmi  1999.0     129.0    Action, Drama
# 15506                           Zulmi Raj  2005.0       NaN           Action
# 15507                       Zulmi Shikari  1988.0       NaN           Action
# 15508                        Zulm-O-Sitam  1998.0     130.0    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df.Votes
# Out:
# 0        NaN
# 1          8
# 2        NaN
# 3         35
# 4        NaN
#         ...
# 15504     11
# 15505    655
# 15506    NaN
# 15507    NaN
# 15508     20
# Name: Votes, Length: 15503, dtype: object

# %%
df['Votes']=df['Votes'].astype(str)

# %%
df
# Out:
#                                      Name    Year  Duration            Genre  \
# 0                                             NaN       NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                             #Homecoming  2021.0      90.0   Drama, Musical
# 3                                 #Yaaram  2019.0     110.0  Comedy, Romance
# 4                       ...And Once Again  2010.0     105.0            Drama
# ...                                   ...     ...       ...              ...
# 15504                 Zulm Ko Jala Doonga  1988.0       NaN           Action
# 15505                               Zulmi  1999.0     129.0    Action, Drama
# 15506                           Zulmi Raj  2005.0       NaN           Action
# 15507                       Zulmi Shikari  1988.0       NaN           Action
# 15508                        Zulm-O-Sitam  1998.0     130.0    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   nan       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   nan  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   nan        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   nan          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   nan                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15503 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15503 non-null  object
#  1   Year      14976 non-null  float64
#  2   Duration  7239 non-null   float64
#  3   Genre     13627 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     15503 non-null  object
#  6   Director  14979 non-null  object
#  7   Actor 1   13888 non-null  object
#  8   Actor 2   13122 non-null  object
#  9   Actor 3   12363 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.3+ MB

# %%
df
# Out:
#                                      Name    Year  Duration            Genre  \
# 0                                             NaN       NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                             #Homecoming  2021.0      90.0   Drama, Musical
# 3                                 #Yaaram  2019.0     110.0  Comedy, Romance
# 4                       ...And Once Again  2010.0     105.0            Drama
# ...                                   ...     ...       ...              ...
# 15504                 Zulm Ko Jala Doonga  1988.0       NaN           Action
# 15505                               Zulmi  1999.0     129.0    Action, Drama
# 15506                           Zulmi Raj  2005.0       NaN           Action
# 15507                       Zulmi Shikari  1988.0       NaN           Action
# 15508                        Zulm-O-Sitam  1998.0     130.0    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   nan       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   nan  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   nan        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   nan          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   nan                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15503 rows x 10 columns]

# %%
df['Votes']=df['Votes'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15503 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15503 non-null  object
#  1   Year      14976 non-null  float64
#  2   Duration  7239 non-null   float64
#  3   Genre     13627 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     15503 non-null  object
#  6   Director  14979 non-null  object
#  7   Actor 1   13888 non-null  object
#  8   Actor 2   13122 non-null  object
#  9   Actor 3   12363 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.3+ MB

# %%
df['Votes']=pd.to_numeric(df['Votes'],errors="coerce")

# %%
df.Votes
# Out:
# 0          NaN
# 1          8.0
# 2          NaN
# 3         35.0
# 4          NaN
#          ...
# 15504     11.0
# 15505    655.0
# 15506      NaN
# 15507      NaN
# 15508     20.0
# Name: Votes, Length: 15503, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15503 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15503 non-null  object
#  1   Year      14976 non-null  float64
#  2   Duration  7239 non-null   float64
#  3   Genre     13627 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     6548 non-null   float64
#  6   Director  14979 non-null  object
#  7   Actor 1   13888 non-null  object
#  8   Actor 2   13122 non-null  object
#  9   Actor 3   12363 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.3+ MB

# %%
df.dropna(subset=['Genre','Name','Director','Actor 1','Actor 2','Actor 3'],inplace=True)

# %%
df
# Out:
#                                      Name    Year  Duration  \
# 0                                             NaN       NaN
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2                             #Homecoming  2021.0      90.0
# 3                                 #Yaaram  2019.0     110.0
# 4                       ...And Once Again  2010.0     105.0
# ...                                   ...     ...       ...
# 15502                       Zulm Ki Pukar  1979.0       NaN
# 15503                     Zulm Ki Zanjeer  1989.0     125.0
# 15504                 Zulm Ko Jala Doonga  1988.0       NaN
# 15505                               Zulmi  1999.0     129.0
# 15508                        Zulm-O-Sitam  1998.0     130.0
#
#                       Genre  Rating  Votes            Director  \
# 0                     Drama     NaN    NaN       J.S. Randhawa
# 1                     Drama     7.0    8.0       Gaurav Bakshi
# 2            Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3           Comedy, Romance     4.4   35.0          Ovais Khan
# 4                     Drama     NaN    NaN        Amol Palekar
# ...                     ...     ...    ...                 ...
# 15502                Action     NaN    NaN     Dinesh-Ramanesh
# 15503  Action, Crime, Drama     5.8   44.0     S.P. Muthuraman
# 15504                Action     4.6   11.0       Mahendra Shah
# 15505         Action, Drama     4.5  655.0          Kuku Kohli
# 15508         Action, Drama     6.2   20.0        K.C. Bokadia
#
#                 Actor 1             Actor 2          Actor 3
# 0              Manmauji              Birbal  Rajendra Bhatia
# 1          Rasika Dugal      Vivek Ghamande    Arvind Jangid
# 2          Sayani Gupta   Plabita Borthakur       Roy Angana
# 3               Prateik          Ishita Raj  Siddhant Kapoor
# 4          Rajat Kapoor  Rituparna Sengupta      Antara Mali
# ...                 ...                 ...              ...
# 15502       Ramesh Puri          Jalal Agha     Valerie Agha
# 15503       Chiranjeevi          Jayamalini      Rajinikanth
# 15504  Naseeruddin Shah       Sumeet Saigal    Suparna Anand
# 15505      Akshay Kumar      Twinkle Khanna      Aruna Irani
# 15508        Dharmendra          Jaya Prada      Arjun Sarja
#
# [11367 rows x 10 columns]

# %%
df['Duration']=df['Duration'].fillna(df['Duration'].median())

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %%
df['Year']=df['Year'].fillna(df['Year'].median())

# %%
df['Votes']=df['Votes'].fillna(df['Votes'].mean())

# %%
df
# Out:
#                                      Name    Year  Duration  \
# 0                                          1995.0     133.0
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2                             #Homecoming  2021.0      90.0
# 3                                 #Yaaram  2019.0     110.0
# 4                       ...And Once Again  2010.0     105.0
# ...                                   ...     ...       ...
# 15502                       Zulm Ki Pukar  1979.0     133.0
# 15503                     Zulm Ki Zanjeer  1989.0     125.0
# 15504                 Zulm Ko Jala Doonga  1988.0     133.0
# 15505                               Zulmi  1999.0     129.0
# 15508                        Zulm-O-Sitam  1998.0     130.0
#
#                       Genre    Rating       Votes            Director  \
# 0                     Drama  5.811127  125.703943       J.S. Randhawa
# 1                     Drama  7.000000    8.000000       Gaurav Bakshi
# 2            Drama, Musical  5.811127  125.703943  Soumyajit Majumdar
# 3           Comedy, Romance  4.400000   35.000000          Ovais Khan
# 4                     Drama  5.811127  125.703943        Amol Palekar
# ...                     ...       ...         ...                 ...
# 15502                Action  5.811127  125.703943     Dinesh-Ramanesh
# 15503  Action, Crime, Drama  5.800000   44.000000     S.P. Muthuraman
# 15504                Action  4.600000   11.000000       Mahendra Shah
# 15505         Action, Drama  4.500000  655.000000          Kuku Kohli
# 15508         Action, Drama  6.200000   20.000000        K.C. Bokadia
#
#                 Actor 1             Actor 2          Actor 3
# 0              Manmauji              Birbal  Rajendra Bhatia
# 1          Rasika Dugal      Vivek Ghamande    Arvind Jangid
# 2          Sayani Gupta   Plabita Borthakur       Roy Angana
# 3               Prateik          Ishita Raj  Siddhant Kapoor
# 4          Rajat Kapoor  Rituparna Sengupta      Antara Mali
# ...                 ...                 ...              ...
# 15502       Ramesh Puri          Jalal Agha     Valerie Agha
# 15503       Chiranjeevi          Jayamalini      Rajinikanth
# 15504  Naseeruddin Shah       Sumeet Saigal    Suparna Anand
# 15505      Akshay Kumar      Twinkle Khanna      Aruna Irani
# 15508        Dharmendra          Jaya Prada      Arjun Sarja
#
# [11367 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df['Genre']=df.groupby('Genre')['Rating'].transform("mean")
df['Director']=df.groupby('Director')['Rating'].transform("mean")
df['Actor 1']=df.groupby('Actor 1')['Rating'].transform("mean")
df['Actor 2']=df.groupby('Actor 2')['Rating'].transform("mean")
df['Actor 3']=df.groupby('Actor 3')['Rating'].transform("mean")
df['Name']=df.groupby('Name')['Rating'].transform("mean")

# %%
df
# Out:
#            Name    Year  Duration     Genre    Rating       Votes  Director  \
# 0      5.811127  1995.0     133.0  6.087890  5.811127  125.703943  5.755564
# 1      7.000000  2019.0     109.0  6.087890  7.000000    8.000000  7.000000
# 2      5.811127  2021.0      90.0  6.383337  5.811127  125.703943  5.811127
# 3      4.400000  2019.0     110.0  5.713171  4.400000   35.000000  4.400000
# 4      5.811127  2010.0     105.0  6.087890  5.811127  125.703943  6.258732
# ...         ...     ...       ...       ...       ...         ...       ...
# 15502  5.811127  1979.0     133.0  5.513266  5.811127  125.703943  6.027782
# 15503  5.800000  1989.0     125.0  5.631964  5.800000   44.000000  5.885714
# 15504  4.600000  1988.0     133.0  5.513266  4.600000   11.000000  4.075000
# 15505  4.500000  1999.0     129.0  5.504964  4.500000  655.000000  5.225000
# 15508  6.200000  1998.0     130.0  5.504964  6.200000   20.000000  4.350000
#
#         Actor 1   Actor 2   Actor 3
# 0      5.811127  5.528580  5.811127
# 1      6.850000  7.000000  7.000000
# 2      6.405564  6.837042  5.811127
# 3      5.420000  4.400000  4.450000
# 4      6.801855  5.758028  5.537042
# ...         ...       ...       ...
# 15502  6.142225  6.103709  5.811127
# 15503  6.079432  5.807418  5.839398
# 15504  6.021065  3.700000  4.600000
# 15505  5.500639  4.645455  5.660251
# 15508  5.745477  5.519381  5.104451
#
# [11367 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11367 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11367 non-null  float64
#  1   Year      11367 non-null  float64
#  2   Duration  11367 non-null  float64
#  3   Genre     11367 non-null  float64
#  4   Rating    11367 non-null  float64
#  5   Votes     11367 non-null  float64
#  6   Director  11367 non-null  float64
#  7   Actor 1   11367 non-null  float64
#  8   Actor 2   11367 non-null  float64
#  9   Actor 3   11367 non-null  float64
# dtypes: float64(10)
# memory usage: 976.9 KB

# %%
x = df.drop(['Rating'],axis=1)
y =df['Rating']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

li = LinearRegression()

log_model = li.fit(x_train,y_train)

# %%
y_pred = log_model.predict(x_test)

# %%
y_pred
# Out:
# array([5.83871566, 5.18110941, 7.0368351 , ..., 5.09865379, 8.25688701,
#        5.86630437])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,root_mean_squared_error

# %%
print(f"{r2_score(y_test,y_pred)}")
# Out:
# 0.930865840060082
